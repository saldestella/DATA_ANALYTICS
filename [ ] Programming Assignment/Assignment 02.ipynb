# %% [markdown]
# $\textbf{PROGRAMMING #2 ASSIGNMENT}$
# ---
# Data: https://archive.ics.uci.edu.
#
# Instruction: Choose a dataset and perform a data storytelling, choose the proper data visualization, do not use words, your graphs must tell a story.

# %% [markdown]
# ## Assignment 2
# Name: Sheena Stella Salde <br>
# Dataset: Wine (https://archive.ics.uci.edu/dataset/109/wine) <br>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.preprocessing import LabelEncoder

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data"
columns = [
    'Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium',
    'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins',
    'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline'
]
df = pd.read_csv(url, names=columns)

le = LabelEncoder()
df['Class'] = le.fit_transform(df['Class'])

# %%
# Bar Chart: Distribution of Wine Classes
plt.figure(figsize=(8, 6))
sns.countplot(x='Class', data=df, palette='viridis')
plt.title('Distribution of Wine Classes')
plt.xlabel('Wine Class')
plt.ylabel('Count')
plt.show()

# %%
# Line Plot: Alcohol Content by Class
plt.figure(figsize=(10, 6))
sns.regplot(x='Alcohol', y='Proline', data=df, scatter_kws={"color": "black"}, line_kws={"color": "red"})
plt.title('Linear Relationship between Alcohol and Proline')
plt.xlabel('Alcohol')
plt.ylabel('Proline')
plt.show()

# %%
# Linear Plot: Relationship between Alcohol and Proline
X = df[['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 
        'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']]
y = df['Class']


plt.figure(figsize=(10, 6))
coefficients = pd.Series(logreg.coef_[0], index=X.columns)
coefficients.sort_values().plot(kind='barh', color='skyblue')
plt.title('Logistic Regression Coefficients for Wine Class Prediction')
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.show()

# %%
# Logistic Regression: Predicting Wine Class

X = df[['Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 
        'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']]
y = df['Class']

plt.figure(figsize=(10, 6))
coefficients = pd.Series(logreg.coef_[0], index=X.columns)
coefficients.sort_values().plot(kind='barh', color='skyblue')
plt.title('Logistic Regression Coefficients for Wine Class Prediction')
plt.xlabel('Coefficient Value')
plt.ylabel('Feature')
plt.show()

# %%
# Pie Chart: Proportion of Wine Classes
plt.figure(figsize=(8, 8))
df['Class'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('viridis'), startangle=140)
plt.title('Proportion of Wine Classes')
plt.ylabel('')
plt.show()

# %%
# Scatter Plot: Color Intensity vs.Hue by Class
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Color intensity', y='Hue', hue='Class', palette='viridis', data=df, s=100, alpha=0.7)
plt.title('Scatter Plot of Color Intensity vs. Hue by Class')
plt.xlabel('Color Intensity')
plt.ylabel('Hue')
plt.legend(title='Class')
plt.show()

# %%
# Time Series: Simulated Proline Levels Over Time
df.replace([np.inf, -np.inf], np.nan, inplace=True)

df.dropna(inplace=True)

df['Time'] = pd.date_range(start='2023-01-01', periods=len(df), freq='D')

# Plot Proline levels over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='Time', y='Proline', hue='Class', data=df, palette='viridis')
plt.title('Simulated Time Series of Proline Levels')
plt.xlabel('Time')
plt.ylabel('Proline')
plt.legend(title='Class')
plt.show()
# Out:
# C:\Users\stell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\stell\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
